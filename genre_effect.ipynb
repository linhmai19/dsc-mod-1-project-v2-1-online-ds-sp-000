# %% [markdown]
# # The 2nd question: Which movie genres do the top 300 recent movies have?

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import math
from numpy import int64
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Import data files and clean data

# %% [markdown]
# ### Data cleaning for 'imdb_basic' dataset

# %%
imdb_basic = pd.read_csv('data/title.basics.csv')
print(imdb_basic.shape)
print(imdb_basic.isna().sum())
# Out:
# (146144, 6)
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#Choose data for recent movies (from 2000 to 2018)
imdb_basic = imdb_basic.loc[(imdb_basic['start_year'] >= 2000) & (imdb_basic['start_year'] <= 2018)].copy()

print(imdb_basic.isna().sum())
print(imdb_basic.shape)
imdb_basic.head()
# Out:
# tconst                 0
# primary_title          0
# original_title        19
# start_year             0
# runtime_minutes    26887
# genres              5038
# dtype: int64
# (136702, 6)
#       tconst               primary_title              original_title  \
# 0  tt0063540                   Sunghursh                   Sunghursh
# 2  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204             Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275    The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                 A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy

# %% [markdown]
# #### Comment:
# The missing values in 'genres' columns is only about 3.6%, compared to the size of the dataset. Therefore, any NaN value will be replaced with a string called "No Defined" and will be treated as its own category

# %%
imdb_basic['genres'].fillna('No Defined', inplace=True)
imdb_basic.head()
# Out:
#       tconst               primary_title              original_title  \
# 0  tt0063540                   Sunghursh                   Sunghursh
# 2  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204             Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275    The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                 A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy

# %%
#Check to see if there is still NaN in the 'genre' column
print(imdb_basic.isna().sum())
print(imdb_basic.shape)
# Out:
# tconst                 0
# primary_title          0
# original_title        19
# start_year             0
# runtime_minutes    26887
# genres                 0
# dtype: int64
# (136702, 6)

# %% [markdown]
# ### Data cleaning for 'tmdb_movie' dataset

# %%
tmdb_movie = pd.read_csv('data/tmdb.movies.csv')
print(tmdb_movie.shape)
print(tmdb_movie.isna().sum())
tmdb_movie.head()
# Out:
# (26517, 10)
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#Remove the 'unnamed' column and set 'id' column as index
tmdb_movie = tmdb_movie.drop('Unnamed: 0', 1)
tmdb_movie.set_index('id', inplace=True)

# %%
#Drop unnecessary columns 
tmdb_movie = tmdb_movie.drop(['genre_ids', 'original_language'], axis=1).copy()
tmdb_movie.head()
# Out:
#                                      original_title  popularity release_date  \
# id
# 12444  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 10191                      How to Train Your Dragon      28.734   2010-03-26
# 10138                                    Iron Man 2      28.515   2010-05-07
# 862                                       Toy Story      28.005   1995-11-22
# 27205                                     Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count
# id
# 12444  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 10191                      How to Train Your Dragon           7.7        7610
# 10138                                    Iron Man 2           6.8       12368
# 862                                       Toy Story           7.9       10174
# 27205                                     Inception           8.3       22186

# %%
#change the type of 'release_date' column from object to datetime 
tmdb_movie['release_date'] = pd.to_datetime(tmdb_movie['release_date'])
print(tmdb_movie['release_date'].dtype)
# Out:
# datetime64[ns]

# %%
#Choose only recent movies: from 2000 to 2018
tmdb_movie = tmdb_movie[(tmdb_movie['release_date'] > '2000-01-01') 
                                      & (tmdb_movie['release_date'] <= '2018-12-31')].copy()
tmdb_movie.head()
# Out:
#                                           original_title  popularity  \
# id
# 12444       Harry Potter and the Deathly Hallows: Part 1      33.533
# 10191                           How to Train Your Dragon      28.734
# 10138                                         Iron Man 2      28.515
# 27205                                          Inception      27.920
# 32657  Percy Jackson & the Olympians: The Lightning T...      26.691
#
#       release_date                                              title  \
# id
# 12444   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 10191   2010-03-26                           How to Train Your Dragon
# 10138   2010-05-07                                         Iron Man 2
# 27205   2010-07-16                                          Inception
# 32657   2010-02-11  Percy Jackson & the Olympians: The Lightning T...
#
#        vote_average  vote_count
# id
# 12444           7.7       10788
# 10191           7.7        7610
# 10138           6.8       12368
# 27205           8.3       22186
# 32657           6.1        4229

# %% [markdown]
# ### Data cleaning for 'tn_budget' dataset

# %%
tn_budget = pd.read_csv('data/tn.movie_budgets.csv')
print(tn_budget.shape)
print(tn_budget.isna().sum())
tn_budget.head()
# Out:
# (5782, 6)
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Rename 'movie' column and set 'id' column as index
tn_budget = tn_budget.rename(columns={'movie': 'title'}).copy()
tn_budget.set_index('id', inplace=True)
tn_budget.head()
# Out:
#     release_date                                        title  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
#Remove the '$' sign and comma ',' and change the type to int for production_budget and worldwide_gross columns
tn_budget['production_budget'] = tn_budget['production_budget'].str.replace('$','').str.replace(',','').astype(int64)
tn_budget['worldwide_gross'] = tn_budget['worldwide_gross'].str.replace('$','').str.replace(',','').astype(int64)
tn_budget['domestic_gross'] = tn_budget['domestic_gross'].str.replace('$','').str.replace(',','').astype(int64)

# %%
#Calculate the profit from production_budget and worldwide_gross and store it to a new column named 'profit'
tn_budget['profit'] = (tn_budget['worldwide_gross'] - tn_budget['production_budget'])
tn_budget['profit'] = tn_budget['profit'].astype(int64)

# %%
#change the type of 'release_date' column from object to datetime 
tn_budget['release_date'] = pd.to_datetime(tn_budget['release_date'])
#Choose only recent movies: from 2000 to 2018
tn_budget = tn_budget[(tn_budget['release_date'] > '2000-01-01') 
                                      & (tn_budget['release_date'] <= '2018-12-31')].copy()
tn_budget.head()
# Out:
#    release_date                                        title  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 6    2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#     production_budget  domestic_gross  worldwide_gross      profit
# id
# 1           425000000       760507625       2776345279  2351345279
# 2           410600000       241063875       1045663875   635063875
# 4           330600000       459005868       1403013963  1072413963
# 5           317000000       620181382       1316721747   999721747
# 6           306000000       936662225       2053311220  1747311220

# %% [markdown]
# ### Create new SQL databases and import three existing Pandas dataframes to them

# %%
#Create a new SQL database
conn = sqlite3.connect('genre_popularity.db')
cur = conn.cursor()

# %%
#Create a new table 'genre' in the SQL database
cur.execute('''CREATE TABLE genre(tconst INTEGER,
                                  primary_title TEXT,
                                  original_title TEXT,
                                  start_year INTEGER,
                                  runtime_minutes REAL,
                                  genres TEXT);''')
conn.commit()

# %%
#Get from Pandas DataFrame 'imdb_basic' to SQL
imdb_basic.to_sql('genre', conn, if_exists='replace')

# %%
#Review the data from 'genre' table
cur.execute('''SELECT * FROM genre;''')
df1 = pd.DataFrame(cur.fetchall())
df1.columns = [i[0] for i in cur.description]
df1.head()
# Out:
#    index     tconst               primary_title              original_title  \
# 0      0  tt0063540                   Sunghursh                   Sunghursh
# 1      2  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 2      3  tt0069204             Sabse Bada Sukh             Sabse Bada Sukh
# 3      4  tt0100275    The Wandering Soap Opera       La Telenovela Errante
# 4      5  tt0111414                 A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2018            122.0                 Drama
# 2        2018              NaN          Comedy,Drama
# 3        2017             80.0  Comedy,Drama,Fantasy
# 4        2018             75.0                Comedy

# %%
#Create a new table 'mov_pop' in the SQL database
cur.execute('''CREATE TABLE mov_pop(id INTEGER,
                                    original_title TEXT,
                                    popularity REAL,
                                    release_date DATE,
                                    title TEXT,
                                    vote_average REAL,
                                    vote_count INTEGER);''')
conn.commit()

# %%
#Get from Pandas DataFrame 'tmdb_movie' to SQL
tmdb_movie.to_sql('mov_pop', conn, if_exists='replace')

# %%
#Review the data from 'mov_pop' table
cur.execute('''SELECT * FROM mov_pop;''')
df2 = pd.DataFrame(cur.fetchall())
df2.columns = [i[0] for i in cur.description]
df2.head()
# Out:
#       id                                     original_title  popularity  \
# 0  12444       Harry Potter and the Deathly Hallows: Part 1      33.533
# 1  10191                           How to Train Your Dragon      28.734
# 2  10138                                         Iron Man 2      28.515
# 3  27205                                          Inception      27.920
# 4  32657  Percy Jackson & the Olympians: The Lightning T...      26.691
#
#           release_date                                              title  \
# 0  2010-11-19 00:00:00       Harry Potter and the Deathly Hallows: Part 1
# 1  2010-03-26 00:00:00                           How to Train Your Dragon
# 2  2010-05-07 00:00:00                                         Iron Man 2
# 3  2010-07-16 00:00:00                                          Inception
# 4  2010-02-11 00:00:00  Percy Jackson & the Olympians: The Lightning T...
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           8.3       22186
# 4           6.1        4229

# %%
#Create a new table 'mov_pro' in the SQL database
cur.execute('''CREATE TABLE mov_pro(release_date DATE,
                                    title TEXT,
                                    production_budget INTEGER,
                                    domestic_gross INTEGER,
                                    worldwide_gross INTEGER,
                                    profit INTERGER);''')                                
conn.commit()

# %%
#Get from Pandas DataFrame 'tn_budget' to SQL
tn_budget.to_sql('mov_pro', conn, if_exists='replace')

# %%
#Review the data from 'mov_pro' table
cur.execute('''SELECT * FROM mov_pro;''')
df3 = pd.DataFrame(cur.fetchall())
df3.columns = [i[0] for i in cur.description]
df3.head()
# Out:
#    id         release_date                                        title  \
# 0   1  2009-12-18 00:00:00                                       Avatar
# 1   2  2011-05-20 00:00:00  Pirates of the Caribbean: On Stranger Tides
# 2   4  2015-05-01 00:00:00                      Avengers: Age of Ultron
# 3   5  2017-12-15 00:00:00            Star Wars Ep. VIII: The Last Jedi
# 4   6  2015-12-18 00:00:00         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross      profit
# 0          425000000       760507625       2776345279  2351345279
# 1          410600000       241063875       1045663875   635063875
# 2          330600000       459005868       1403013963  1072413963
# 3          317000000       620181382       1316721747   999721747
# 4          306000000       936662225       2053311220  1747311220

# %% [markdown]
# ## Common genres of the most 300 popular movies from 2000 to 2018

# %%
#Choose only 300 movies (from 2000 to 2018) that have popularity rates in descending order
cur.execute('''SELECT mov_pop.*, genre.original_title, start_year, genres
               FROM genre
               JOIN mov_pop
               ON genre.original_title = mov_pop.original_title
               ORDER BY popularity DESC
               LIMIT 300;''')
top_gen_pop = pd.DataFrame(cur.fetchall())
top_gen_pop.columns = [i[0] for i in cur.description]
top_gen_pop.head(10)
# Out:
#        id                               original_title  popularity  \
# 0  299536                       Avengers: Infinity War      80.773
# 1  245891                                    John Wick      78.123
# 2  324857            Spider-Man: Into the Spider-Verse      60.534
# 3  122917    The Hobbit: The Battle of the Five Armies      53.783
# 4   24428                                 The Avengers      50.289
# 5  118340                      Guardians of the Galaxy      49.606
# 6  335984                            Blade Runner 2049      48.571
# 7  335984                            Blade Runner 2049      48.571
# 8  338952  Fantastic Beasts: The Crimes of Grindelwald      48.508
# 9  404368                    Ralph Breaks the Internet      48.057
#
#           release_date                                        title  \
# 0  2018-04-27 00:00:00                       Avengers: Infinity War
# 1  2014-10-24 00:00:00                                    John Wick
# 2  2018-12-14 00:00:00            Spider-Man: Into the Spider-Verse
# 3  2014-12-17 00:00:00    The Hobbit: The Battle of the Five Armies
# 4  2012-05-04 00:00:00                                 The Avengers
# 5  2014-08-01 00:00:00                      Guardians of the Galaxy
# 6  2017-10-06 00:00:00                            Blade Runner 2049
# 7  2017-10-06 00:00:00                            Blade Runner 2049
# 8  2018-11-16 00:00:00  Fantastic Beasts: The Crimes of Grindelwald
# 9  2018-11-21 00:00:00                    Ralph Breaks the Internet
#
#    vote_average  vote_count                               original_title  \
# 0           8.3       13948                       Avengers: Infinity War
# 1           7.2       10081                                    John Wick
# 2           8.4        4048            Spider-Man: Into the Spider-Verse
# 3           7.3        8392    The Hobbit: The Battle of the Five Armies
# 4           7.6       19673                                 The Avengers
# 5           7.9       17958                      Guardians of the Galaxy
# 6           7.4        6679                            Blade Runner 2049
# 7           7.4        6679                            Blade Runner 2049
# 8           6.9        4870  Fantastic Beasts: The Crimes of Grindelwald
# 9           7.2        2626                    Ralph Breaks the Internet
#
#    start_year                      genres
# 0        2018     Action,Adventure,Sci-Fi
# 1        2014       Action,Crime,Thriller
# 2        2018  Action,Adventure,Animation
# 3        2014           Adventure,Fantasy
# 4        2012     Action,Adventure,Sci-Fi
# 5        2014     Action,Adventure,Comedy
# 6        2017        Drama,Mystery,Sci-Fi
# 7        2017        Drama,Mystery,Sci-Fi
# 8        2018    Adventure,Family,Fantasy
# 9        2018  Adventure,Animation,Comedy

# %%
#Make each row in the 'genres' column to a list
top_gen_pop['genres'] = top_gen_pop['genres'].map(lambda x: x.split(',') if x else x)
top_gen_pop['genres'].head()
# Out:
# 0       [Action, Adventure, Sci-Fi]
# 1         [Action, Crime, Thriller]
# 2    [Action, Adventure, Animation]
# 3              [Adventure, Fantasy]
# 4       [Action, Adventure, Sci-Fi]
# Name: genres, dtype: object

# %%
#Split the types of genres into a big list
all_genres =[]
for genre in top_gen_pop['genres']:
    all_genres += genre

all_genres
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'No Defined',
#  'Action',
#  'Adventure',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Music',
#  'Action',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Music',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Fantasy',
#  'Mystery',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Mystery',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Documentary',
#  'Drama',
#  'Sport',
#  'Drama',
#  'Romance',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Documentary',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Drama',
#  'War',
#  'Musical',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Music',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'History',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Adventure',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'No Defined',
#  'No Defined',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Horror',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Romance',
#  'Sport',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Documentary',
#  'History',
#  'No Defined',
#  'No Defined',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Horror',
#  'Sci-Fi',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Crime',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Mystery',
#  'Action',
#  'Fantasy',
#  'War',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Sci-Fi',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Documentary',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Documentary',
#  'Fantasy',
#  'Musical',
#  'Biography',
#  'Drama',
#  'Musical',
#  'Biography',
#  'Drama',
#  'Musical',
#  'Comedy',
#  'Comedy',
#  'Fantasy',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Western',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Action',
#  'Action',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Crime',
#  'Documentary',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Horror',
#  'Mystery',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Family',
#  'Documentary',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Family',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Comedy',
#  'Family']

# %%
#Convert any of the iterable to sequence of iterable genres with dintinct genres
unique_genres = set(all_genres)

# %%
#Count the number of each genre
num_genre = {}
for genre in unique_genres:
    num_genre[genre] = all_genres.count(genre)

num_genre
# Out:
# {'Documentary': 9,
#  'Comedy': 58,
#  'Action': 143,
#  'Musical': 9,
#  'Music': 5,
#  'Biography': 16,
#  'Animation': 25,
#  'Crime': 40,
#  'Thriller': 46,
#  'Fantasy': 48,
#  'War': 2,
#  'Family': 25,
#  'Sport': 6,
#  'Sci-Fi': 58,
#  'Adventure': 139,
#  'History': 8,
#  'Horror': 22,
#  'Mystery': 26,
#  'No Defined': 5,
#  'Romance': 12,
#  'Western': 1,
#  'Drama': 102}

# %%
#Make 2 lists for name of genre and number of genre
genres = []
counts = []

for genre, count in num_genre.items():
    genres.append(genre)
    counts.append(count)

# %%
#graph to see the trend
plt.figure(figsize=(10, 7))
sns.set_style('dark')
gr1 = sns.barplot(x=counts, y=genres,
                  ci=None, palette='ch:2.5,-.2,dark=.3')
gr1.set_xlabel('Number of Movies', fontsize=12, alpha=0.8)
gr1.set_ylabel('Genres', fontsize=12, alpha=0.8)
gr1.set_title('Genres of top 300 popular movies from 2000 to 2018', fontsize=14)
plt.show()

# %% [markdown]
# #### Comment:
# The top 300 popular recent movies have genres in Action, Adventure, Drama, Comedy, and Sci-Fi

# %% [markdown]
# ## Common genres of the most 300 profitable from 2000 to 2018

# %%
#Connect 'genre' and 'mov_pro' tables, choose 300 movies from 2000 to 2018 that are the most profitable
cur.execute('''SELECT mov_pro.*, original_title, start_year, genres
               FROM genre
               JOIN mov_pro
               ON genre.original_title = mov_pro.title
               ORDER BY profit DESC
               LIMIT 300;''')
top_pro_genre = pd.DataFrame(cur.fetchall())
top_pro_genre.columns = [i[0] for i in cur.description]
print(top_pro_genre.shape)
top_pro_genre.head()
# Out:
# (300, 10)
#    id         release_date                           title  production_budget  \
# 0   7  2018-04-27 00:00:00          Avengers: Infinity War          300000000
# 1  34  2015-06-12 00:00:00                  Jurassic World          215000000
# 2  27  2012-05-04 00:00:00                    The Avengers          225000000
# 3  42  2018-02-16 00:00:00                   Black Panther          200000000
# 4  13  2018-06-22 00:00:00  Jurassic World: Fallen Kingdom          170000000
#
#    domestic_gross  worldwide_gross      profit  \
# 0       678815482       2048134200  1748134200
# 1       652270625       1648854864  1433854864
# 2       623279547       1517935897  1292935897
# 3       700059566       1348258224  1148258224
# 4       417719760       1305772799  1135772799
#
#                    original_title  start_year                   genres
# 0          Avengers: Infinity War        2018  Action,Adventure,Sci-Fi
# 1                  Jurassic World        2015  Action,Adventure,Sci-Fi
# 2                    The Avengers        2012  Action,Adventure,Sci-Fi
# 3                   Black Panther        2018  Action,Adventure,Sci-Fi
# 4  Jurassic World: Fallen Kingdom        2018  Action,Adventure,Sci-Fi

# %%
#Make each row in the 'genres' column to a list
top_pro_genre['genres'] = top_pro_genre['genres'].map(lambda x: x.split(',') if x else x)
top_pro_genre['genres'].head()
# Out:
# 0    [Action, Adventure, Sci-Fi]
# 1    [Action, Adventure, Sci-Fi]
# 2    [Action, Adventure, Sci-Fi]
# 3    [Action, Adventure, Sci-Fi]
# 4    [Action, Adventure, Sci-Fi]
# Name: genres, dtype: object

# %%
#Split the types of genres into a big list
all_genres_pro =[]
for genre in top_pro_genre['genres']:
    all_genres_pro += genre

all_genres_pro
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Music',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Documentary',
#  'Fantasy',
#  'Musical',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Documentary',
#  'History',
#  'No Defined',
#  'No Defined',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Documentary',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'No Defined',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Horror',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Mystery',
#  'Comedy',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Biography',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Sci-Fi',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Musical',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Music',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Animation',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Documentary',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Documentary',
#  'Thriller',
#  'Documentary',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Drama',
#  'Western',
#  'Action',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Thriller',
#  'Documentary',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Sci-Fi',
#  'Drama',
#  'Action',
#  'Drama',
#  'Family',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Musical',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Biography',
#  'Drama',
#  'Action',
#  'Drama',
#  'Family',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Thriller',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Romance',
#  'Sport',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Comedy',
#  'Music',
#  'Comedy',
#  'Romance',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Horror',
#  'Biography',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Biography',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Family',
#  'Documentary',
#  'Documentary',
#  'Family',
#  'Animation',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Documentary',
#  'Action',
#  'History',
#  'War',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Animation',
#  'Documentary',
#  'Family',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Fantasy',
#  'War',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Western',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Biography',
#  'Documentary',
#  'History',
#  'Comedy',
#  'Romance',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'No Defined',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Mystery',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Biography',
#  'Drama']

# %%
#Convert any of the iterable to sequence of iterable genres with dintinct genres
unique_genres_pro = set(all_genres_pro)

# %%
#Count the number of each genre
num_genre_pro = {}
for genre in unique_genres_pro:
    num_genre_pro[genre] = all_genres_pro.count(genre)

num_genre_pro
# Out:
# {'Documentary': 26,
#  'Comedy': 77,
#  'Action': 123,
#  'Musical': 6,
#  'Music': 4,
#  'Biography': 15,
#  'Animation': 56,
#  'Crime': 13,
#  'Thriller': 40,
#  'Fantasy': 33,
#  'War': 2,
#  'Family': 27,
#  'Sport': 4,
#  'Sci-Fi': 53,
#  'Adventure': 144,
#  'History': 6,
#  'Horror': 18,
#  'Mystery': 15,
#  'No Defined': 4,
#  'Romance': 13,
#  'Western': 2,
#  'Drama': 73}

# %%
#Make 2 lists for name of genre and number of genre
genres_pro = []
counts_pro = []

for genre, count in num_genre_pro.items():
    genres_pro.append(genre)
    counts_pro.append(count)

# %%
#graph to see the trend
plt.figure(figsize=(10, 7))
sns.set_style('dark')
gr2 = sns.barplot(x=counts_pro, y=genres_pro,
                  ci=None, palette='Blues_d')
gr2.set_xlabel('Number of Movies', fontsize=12, alpha=0.8)
gr2.set_ylabel('Genres', fontsize=12, alpha=0.8)
gr2.set_title('Genres of top 300 profitable movies from 2000 to 2018', fontsize=14)
plt.show()

# %% [markdown]
# #### Comment:
# The top 300 profitable recent movies have genres in Action, Adventure, Comedy, Drama, Animation, and Sci-Fi

# %% [markdown]
# ## FINAL RESULTS

# %%
top_genre = plt.figure(figsize=(18, 10))
g_pop = top_genre.add_subplot(121)
g_pro = top_genre.add_subplot(122)
sns.set(style='darkgrid', context='talk')

sns.barplot(x=counts, y=genres, ax=g_pop, 
            ci=None, palette='gist_heat')
sns.barplot(x=counts_pro, y=genres_pro, ax=g_pro, 
            ci=None, palette='gist_heat')

g_pop.set_title('Genre of Top 300 popular movies', fontsize=16)
g_pop.set_xlabel('Number of Movie', fontsize=14, alpha=0.8)
g_pop.set_ylabel('Genre', fontsize=14, alpha=0.8)

g_pro.set_title('Genre of Top 300 profitable movies', fontsize=16)
g_pro.set_xlabel('Day of the Week', fontsize=14, alpha=0.8)
g_pro.set_ylabel('', fontsize=14, alpha=0.8)

plt.subplots_adjust(wspace = 0.3)
plt.show()
